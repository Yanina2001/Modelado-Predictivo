# %%
# Execute if necessary
# %%capture
# !pip install numpy seaborn matplotlib pandas

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from typing import Dict, Tuple, Union, List

# %% [markdown]
# # Práctica 3: Modelo Lineal

# %% [markdown]
# __Instrucciones__: A continuación hay una lista de funciones que debe implementar o tareas que debe desarrollar. La descripción de cada una de ellas se encuentra en la definición de cada una de las funciones. Cada función está marcada por &#x1F625;,  &#x1F643; o &#x1F921;. Las marcas indican:
#
# - &#x1F625;: Indican una entrega que debe ser hecha dentro de la misma sesión de la asignación.
# - &#x1F643;: Indican una entrega que puede ser hecha hasta la siguiente sesión.
# - &#x1F921;: Debe mostrar un avance en la misma sesión, pero la entrega puede ser hecha en la siguiente.
#
# Aquellas entregas parciales que no sean hechas el día de la asignación ya no serán válidas para las entregas totales, sin embargo, las entregas totales seguirán siendo válidas.

# %% [markdown]
# En esta sección se incluye un dataset real. El dataset importado incluye multiples características que describen las condiciones de los pasajeros en el accidente del titanic.
#
# - __PassengerId__: Identificador de cada pasajero.
# - __Survived__: 0 si no sobrevivió al accidente, 1 si lo hizo.
# - __Pclass__: Clase en la que viajaba el pasajero, 1 - Primera clase, 2 - Segunda clase y 3 - Tercera clase.
# - __Name__: Nombre del pasajero.
# - __Sex__: Sexo del pasajero.
# - __Age__: Edad del pasajero.
# - __SibSp__: Número de hermanos más número de esposas con las que viajaba el pasajero.
# - __Parch__: Número de padres más número de hijos con las que viajaba el pasajero.
# - __Ticket__: Número de boleto.
# - __Fare__: Tarifa del boleto del pasajero.
# - __Cabin__: Número de cabina del pasajero.
# - __Embarked__: Puerto de embarcación, C - Cherbourg, Q - Queenstown y S - Southampton.

# %%
df = pd.read_csv("titanic.csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## Asignación 1 &#x1F625;
#
# Realice el preprocesamiento que considere adecuado para que las características __Pclass__, __Sex__, __SibSp__, __Parch__, __Fare__, __Cabin__, __Embarked__ y __Survived__ puedan ser utilizadas por un modelo lineal.

# %%
selected_features = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived']
df_selected = df[selected_features]

# Imputar los valores faltantes en la columna 'Fare'
fare_median = df_selected['Fare'].median()
df_selected['Fare'] = df_selected['Fare'].fillna(fare_median)

# Crear una nueva columna para indicar si el pasajero tenía o no asignada una cabina
df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)

# Eliminar la columna original de Cabin
df_selected.drop(['Cabin'], axis=1, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2975337610.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Fare'] = df_selected['Fare'].fillna(fare_median)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2975337610.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2975337610.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.drop(['Cabin'], axis=1, inplace=True)

# %%
# Convertir las características categóricas en variables dummy
sex_dummies = pd.get_dummies(df_selected['Sex'], prefix='Sex')
embarked_dummies = pd.get_dummies(df_selected['Embarked'], prefix='Embarked')
df_selected = pd.concat([df_selected, sex_dummies, embarked_dummies], axis=1)
df_selected.drop(['Sex', 'Embarked'], axis=1, inplace=True)

# %%
# Normalizar las características numéricas
numeric_features = ['Pclass', 'SibSp', 'Parch', 'Fare']
for feature in numeric_features:
    feature_mean = df_selected[feature].mean()
    feature_std = df_selected[feature].std()
    df_selected[feature] = (df_selected[feature] - feature_mean) / feature_std

print(df_selected)
# Out:
#        Pclass     SibSp     Parch      Fare  Survived  CabinAssigned  \
# 0    0.826913  0.432550 -0.473408 -0.502163         0              0
# 1   -1.565228  0.432550 -0.473408  0.786404         1              1
# 2    0.826913 -0.474279 -0.473408 -0.488580         1              0
# 3   -1.565228  0.432550 -0.473408  0.420494         1              1
# 4    0.826913 -0.474279 -0.473408 -0.486064         0              0
# ..        ...       ...       ...       ...       ...            ...
# 886 -0.369158 -0.474279 -0.473408 -0.386454         0              0
# 887 -1.565228 -0.474279 -0.473408 -0.044356         1              1
# 888  0.826913  0.432550  2.007806 -0.176164         0              0
# 889 -1.565228 -0.474279 -0.473408 -0.044356         1              1
# 890  0.826913 -0.474279 -0.473408 -0.492101         0              0
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# 1             1         0           1           0           0
# 2             1         0           0           0           1
# 3             1         0           0           0           1
# 4             0         1           0           0           1
# ..          ...       ...         ...         ...         ...
# 886           0         1           0           0           1
# 887           1         0           0           0           1
# 888           1         0           0           0           1
# 889           0         1           1           0           0
# 890           0         1           0           1           0
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Asignación 2 &#x1F625;
#
# Utilizando las características __Pclass__, __Sex__, __SibSp__, __Parch__, __Fare__, __Cabin__ y __Embarked__, entrene un clasificador lineal para predecir __Survived__ utilizando el algoritmo _pocket_. Imprima el error obtenido.

# %%
# Paso 1: Importar bibliotecas
from sklearn.model_selection import train_test_split

# Paso 2: Cargar datos
data = pd.read_csv("titanic.csv")

# Paso 3: Preprocesar datos
data = data.drop(["PassengerId", "Name", "Ticket"], axis=1)
data["Sex"] = pd.factorize(data["Sex"])[0]
data["Cabin"] = pd.factorize(data["Cabin"])[0]
data["Embarked"] = pd.factorize(data["Embarked"])[0]
data = data.fillna(data.mean())

# Paso 4: Separar datos en conjuntos de entrenamiento y prueba
X = data.drop("Survived", axis=1)
y = data["Survived"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Paso 5: Definir función de entrenamiento del clasificador
def train(X_train, y_train, X_test, y_test, max_iter=1000):
    # Agregar una columna de unos para el término de sesgo
    X_train = np.hstack((np.ones((X_train.shape[0], 1)), X_train))
    X_test = np.hstack((np.ones((X_test.shape[0], 1)), X_test))

    # Inicializar pesos aleatorios
    w = np.random.randn(X_train.shape[1])

    # Entrenar el clasificador con el algoritmo pocket
    best_w = w
    best_error = np.inf
    error = np.zeros(max_iter)
    for i in range(max_iter):
        y_pred = np.sign(np.dot(X_train, w))
        y_pred[y_pred == 0] = -1
        error[i] = np.mean(y_pred != y_train)

        if error[i] < best_error:
            best_w = w.copy()
            best_error = error[i]

        # Actualizar pesos con el algoritmo de perceptrón
        idx = np.where(y_pred != y_train)[0]
        if len(idx) == 0:
            break
        x = X_train[idx[0]]
        y_true = y_train[idx[0]]
        w = w + y_true * x

    # Calcular error en conjunto de prueba
    y_pred_test = np.sign(np.dot(X_test, best_w))
    y_pred_test[y_pred_test == 0] = -1
    test_error = np.mean(y_pred_test != y_test)

    return best_w, best_error, test_error, error

# Paso 6: Entrenar el clasificador y calcular error de entrenamiento y prueba
w, train_error, test_error, error = train(X_train, y_train, X_test, y_test)

# Imprimir resultados
print("Error de entrenamiento:", train_error)
print("Error de prueba:", test_error)
# Out:
# Error de entrenamiento: 0.6938202247191011
# Error de prueba: 0.7150837988826816

# %% [markdown]
# ## Asignación 3 &#x1F625;
#
# Utilizando las características __Pclass__, __Sex__, __SibSp__, __Parch__, __Cabin__ y __Embarked__, entrene una regresión lineal para predecir __Fare__ utilizando el algoritmo de Ordinary Leasts Squares (OLS). Imprima el valor del error cuadrático medio (MSE).

# %%
# Selección de características y preprocesamiento de datos
selected_features = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Cabin', 'Embarked', 'Fare']
df_selected = df[selected_features]

df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)

df_selected.drop(['Cabin'], axis=1, inplace=True)

sex_dummies = pd.get_dummies(df_selected['Sex'], prefix='Sex')
embarked_dummies = pd.get_dummies(df_selected['Embarked'], prefix='Embarked')
df_selected = pd.concat([df_selected, sex_dummies, embarked_dummies], axis=1)
df_selected.drop(['Sex', 'Embarked'], axis=1, inplace=True)

numeric_features = ['Pclass', 'SibSp', 'Parch', 'Fare']
for feature in numeric_features:
    feature_mean = df_selected[feature].mean()
    feature_std = df_selected[feature].std()
    df_selected[feature] = (df_selected[feature] - feature_mean) / feature_std

# División de los datos en conjunto de entrenamiento y prueba
train_size = int(len(df_selected) * 0.8)
train_set = df_selected[:train_size]
test_set = df_selected[train_size:]

X_train = train_set.drop('Fare', axis=1).values
y_train = train_set['Fare'].values
X_test = test_set.drop('Fare', axis=1).values
y_test = test_set['Fare'].values

# Ajuste de la regresión lineal con el algoritmo OLS
X_train = np.c_[np.ones(X_train.shape[0]), X_train]
coefficients = np.linalg.inv(X_train.T @ X_train) @ X_train.T @ y_train

# Evaluación del rendimiento en el conjunto de prueba
X_test = np.c_[np.ones(X_test.shape[0]), X_test]
y_pred = X_test @ coefficients
mse = np.mean((y_test - y_pred) ** 2)

print(f"Error cuadrático medio (MSE): {np.round(mse, 3)}")
# Out:
# Error cuadrático medio (MSE): 1.109
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2991516030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2991516030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.drop(['Cabin'], axis=1, inplace=True)

# %% [markdown]
# ## Asignación 4 &#x1F921;
#
# Utilizando las características __Pclass__, __Sex__, __SibSp__, __Parch__, __Fare__, __Cabin__ y __Embarked__, entrene un clasificador lineal para predecir la probabilidad de supervivencia __Survived__ utilizando el algoritmo de gradiente descendente estocástico y la entropía cruzada como función de error. Imprima el arror en cada iteración del gradiente.

# %%
import numpy as np

# Selección de características y preprocesamiento de datos
selected_features = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived']
df_selected = df[selected_features]

# Imputar los valores faltantes en la columna 'Fare'
fare_median = df_selected['Fare'].median()
df_selected['Fare'] = df_selected['Fare'].fillna(fare_median)

df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)

df_selected.drop(['Cabin'], axis=1, inplace=True)

sex_dummies = pd.get_dummies(df_selected['Sex'], prefix='Sex')
embarked_dummies = pd.get_dummies(df_selected['Embarked'], prefix='Embarked')
df_selected = pd.concat([df_selected, sex_dummies, embarked_dummies], axis=1)
df_selected.drop(['Sex', 'Embarked'], axis=1, inplace=True)

numeric_features = ['Pclass', 'SibSp', 'Parch', 'Fare']
for feature in numeric_features:
    feature_mean = df_selected[feature].mean()
    feature_std = df_selected[feature].std()
    df_selected[feature] = (df_selected[feature] - feature_mean) / feature_std

# División de los datos en conjunto de entrenamiento y prueba
train_size = int(len(df_selected) * 0.8)
train_set = df_selected[:train_size]
test_set = df_selected[train_size:]

X_train = train_set.drop('Survived', axis=1).values
y_train = train_set['Survived'].values
X_test = test_set.drop('Survived', axis=1).values
y_test = test_set['Survived'].values

# Inicialización de los parámetros del modelo
learning_rate = 0.01
num_iterations = 1000
batch_size = 32
num_batches = int(np.ceil(len(X_train) / batch_size))
theta = np.zeros(X_train.shape[1])

# Definición de la función de entropía cruzada
def cross_entropy_loss(y_true, y_pred):
    epsilon = 1e-5
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

# Entrenamiento del modelo con gradiente descendente estocástico
for i in range(num_iterations):
    batch_indices = np.random.choice(len(X_train), size=batch_size, replace=False)
    X_batch = X_train[batch_indices]
    y_batch = y_train[batch_indices]

    # Cálculo de la predicción y el error en el lote actual
    y_pred = 1 / (1 + np.exp(-X_batch @ theta))
    loss = cross_entropy_loss(y_batch, y_pred)

    # Actualización de los parámetros del modelo
    gradient = X_batch.T @ (y_pred - y_batch)
    theta -= learning_rate * gradient

    # Impresión del error en cada iteración del gradiente
    print(f"Iteración {i+1}/{num_iterations} - Error: {np.round(loss, 5)}")

# Evaluación del rendimiento en el conjunto
y_pred_test = 1 / (1 + np.exp(-X_test @ theta))
y_pred_test_classes = np.round(y_pred_test)
test_accuracy = np.mean(y_pred_test_classes == y_test)

print(f"Exactitud en el conjunto de prueba: {test_accuracy}")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2634519302.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Fare'] = df_selected['Fare'].fillna(fare_median)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2634519302.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['CabinAssigned'] = df_selected['Cabin'].notnull().astype(int)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13436\2634519302.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.drop(['Cabin'], axis=1, inplace=True)
# Iteración 1/1000 - Error: 0.69315
# Iteración 2/1000 - Error: 0.6697
# Iteración 3/1000 - Error: 0.64614
# Iteración 4/1000 - Error: 0.63808
# Iteración 5/1000 - Error: 0.60852
# Iteración 6/1000 - Error: 0.58729
# Iteración 7/1000 - Error: 0.56944
# Iteración 8/1000 - Error: 0.54947
# Iteración 9/1000 - Error: 0.62273
# Iteración 10/1000 - Error: 0.57288
# Iteración 11/1000 - Error: 0.55948
# Iteración 12/1000 - Error: 0.5075
# Iteración 13/1000 - Error: 0.52529
# Iteración 14/1000 - Error: 0.51338
# Iteración 15/1000 - Error: 0.51774
# Iteración 16/1000 - Error: 0.53188
# Iteración 17/1000 - Error: 0.51764
# Iteración 18/1000 - Error: 0.51208
# Iteración 19/1000 - Error: 0.49922
# Iteración 20/1000 - Error: 0.6041
# Iteración 21/1000 - Error: 0.5045
# Iteración 22/1000 - Error: 0.46095
# Iteración 23/1000 - Error: 0.58434
# Iteración 24/1000 - Error: 0.52637
# Iteración 25/1000 - Error: 0.55825
# Iteración 26/1000 - Error: 0.51035
# Iteración 27/1000 - Error: 0.54476
# Iteración 28/1000 - Error: 0.55616
# Iteración 29/1000 - Error: 0.41826
# Iteración 30/1000 - Error: 0.48124
# Iteración 31/1000 - Error: 0.54713
# Iteración 32/1000 - Error: 0.34047
# Iteración 33/1000 - Error: 0.44499
# Iteración 34/1000 - Error: 0.38507
# Iteración 35/1000 - Error: 0.50294
# Iteración 36/1000 - Error: 0.54726
# Iteración 37/1000 - Error: 0.51549
# Iteración 38/1000 - Error: 0.51255
# Iteración 39/1000 - Error: 0.48323
# Iteración 40/1000 - Error: 0.47597
# Iteración 41/1000 - Error: 0.4441
# Iteración 42/1000 - Error: 0.5256
# Iteración 43/1000 - Error: 0.38058
# Iteración 44/1000 - Error: 0.38793
# Iteración 45/1000 - Error: 0.63037
# Iteración 46/1000 - Error: 0.44491
# Iteración 47/1000 - Error: 0.52348
# Iteración 48/1000 - Error: 0.6278
# Iteración 49/1000 - Error: 0.47788
# Iteración 50/1000 - Error: 0.43696
# Iteración 51/1000 - Error: 0.54006
# Iteración 52/1000 - Error: 0.69212
# Iteración 53/1000 - Error: 0.50825
# Iteración 54/1000 - Error: 0.47517
# Iteración 55/1000 - Error: 0.47889
# Iteración 56/1000 - Error: 0.50026
# Iteración 57/1000 - Error: 0.46106
# Iteración 58/1000 - Error: 0.479
# Iteración 59/1000 - Error: 0.40236
# Iteración 60/1000 - Error: 0.53137
# Iteración 61/1000 - Error: 0.41345
# Iteración 62/1000 - Error: 0.5887
# Iteración 63/1000 - Error: 0.56253
# Iteración 64/1000 - Error: 0.35743
# Iteración 65/1000 - Error: 0.401
# Iteración 66/1000 - Error: 0.4157
# Iteración 67/1000 - Error: 0.49344
# Iteración 68/1000 - Error: 0.39184
# Iteración 69/1000 - Error: 0.58451
# Iteración 70/1000 - Error: 0.48656
# Iteración 71/1000 - Error: 0.52006
# Iteración 72/1000 - Error: 0.5156
# Iteración 73/1000 - Error: 0.41254
# Iteración 74/1000 - Error: 0.52611
# Iteración 75/1000 - Error: 0.43963
# Iteración 76/1000 - Error: 0.38849
# Iteración 77/1000 - Error: 0.60193
# Iteración 78/1000 - Error: 0.61251
# Iteración 79/1000 - Error: 0.50099
# Iteración 80/1000 - Error: 0.50308
# Iteración 81/1000 - Error: 0.5633
# Iteración 82/1000 - Error: 0.59439
# Iteración 83/1000 - Error: 0.39792
# Iteración 84/1000 - Error: 0.46546
# Iteración 85/1000 - Error: 0.54535
# Iteración 86/1000 - Error: 0.51062
# Iteración 87/1000 - Error: 0.55593
# Iteración 88/1000 - Error: 0.60225
# Iteración 89/1000 - Error: 0.52424
# Iteración 90/1000 - Error: 0.435
# Iteración 91/1000 - Error: 0.58112
# Iteración 92/1000 - Error: 0.29075
# Iteración 93/1000 - Error: 0.41088
# Iteración 94/1000 - Error: 0.47671
# Iteración 95/1000 - Error: 0.50896
# Iteración 96/1000 - Error: 0.57385
# Iteración 97/1000 - Error: 0.43685
# Iteración 98/1000 - Error: 0.43118
# Iteración 99/1000 - Error: 0.53263
# Iteración 100/1000 - Error: 0.48917
# Iteración 101/1000 - Error: 0.41319
# Iteración 102/1000 - Error: 0.41308
# Iteración 103/1000 - Error: 0.57263
# Iteración 104/1000 - Error: 0.39812
# Iteración 105/1000 - Error: 0.45888
# Iteración 106/1000 - Error: 0.47103
# Iteración 107/1000 - Error: 0.35233
# Iteración 108/1000 - Error: 0.32199
# Iteración 109/1000 - Error: 0.46141
# Iteración 110/1000 - Error: 0.36582
# Iteración 111/1000 - Error: 0.45692
# Iteración 112/1000 - Error: 0.67869
# Iteración 113/1000 - Error: 0.5133
# Iteración 114/1000 - Error: 0.37424
# Iteración 115/1000 - Error: 0.55748
# Iteración 116/1000 - Error: 0.54481
# Iteración 117/1000 - Error: 0.40104
# Iteración 118/1000 - Error: 0.60877
# Iteración 119/1000 - Error: 0.72935
# Iteración 120/1000 - Error: 0.43679
# Iteración 121/1000 - Error: 0.42912
# Iteración 122/1000 - Error: 0.41121
# Iteración 123/1000 - Error: 0.49462
# Iteración 124/1000 - Error: 0.47876
# Iteración 125/1000 - Error: 0.51579
# Iteración 126/1000 - Error: 0.3585
# Iteración 127/1000 - Error: 0.57922
# Iteración 128/1000 - Error: 0.53799
# Iteración 129/1000 - Error: 0.37755
# Iteración 130/1000 - Error: 0.38408
# Iteración 131/1000 - Error: 0.48118
# Iteración 132/1000 - Error: 0.53128
# Iteración 133/1000 - Error: 0.53188
# Iteración 134/1000 - Error: 0.41729
# Iteración 135/1000 - Error: 0.44834
# Iteración 136/1000 - Error: 0.57027
# Iteración 137/1000 - Error: 0.28975
# Iteración 138/1000 - Error: 0.60209
# Iteración 139/1000 - Error: 0.57916
# Iteración 140/1000 - Error: 0.35026
# Iteración 141/1000 - Error: 0.39708
# Iteración 142/1000 - Error: 0.5737
# Iteración 143/1000 - Error: 0.40936
# Iteración 144/1000 - Error: 0.45579
# Iteración 145/1000 - Error: 0.41599
# Iteración 146/1000 - Error: 0.39652
# Iteración 147/1000 - Error: 0.48454
# Iteración 148/1000 - Error: 0.52589
# Iteración 149/1000 - Error: 0.36212
# Iteración 150/1000 - Error: 0.48166
# Iteración 151/1000 - Error: 0.52877
# Iteración 152/1000 - Error: 0.47722
# Iteración 153/1000 - Error: 0.60228
# Iteración 154/1000 - Error: 0.54639
# Iteración 155/1000 - Error: 0.52911
# Iteración 156/1000 - Error: 0.39033
# Iteración 157/1000 - Error: 0.44028
# Iteración 158/1000 - Error: 0.38102
# Iteración 159/1000 - Error: 0.37492
# Iteración 160/1000 - Error: 0.48279
# Iteración 161/1000 - Error: 0.44202
# Iteración 162/1000 - Error: 0.41184
# Iteración 163/1000 - Error: 0.55834
# Iteración 164/1000 - Error: 0.33593
# Iteración 165/1000 - Error: 0.46164
# Iteración 166/1000 - Error: 0.60572
# Iteración 167/1000 - Error: 0.34528
# Iteración 168/1000 - Error: 0.56657
# Iteración 169/1000 - Error: 0.60906
# Iteración 170/1000 - Error: 0.42932
# Iteración 171/1000 - Error: 0.55649
# Iteración 172/1000 - Error: 0.47076
# Iteración 173/1000 - Error: 0.64193
# Iteración 174/1000 - Error: 0.3841
# Iteración 175/1000 - Error: 0.70058
# Iteración 176/1000 - Error: 0.59363
# Iteración 177/1000 - Error: 0.41959
# Iteración 178/1000 - Error: 0.4265
# Iteración 179/1000 - Error: 0.38346
# Iteración 180/1000 - Error: 0.33102
# Iteración 181/1000 - Error: 0.33332
# Iteración 182/1000 - Error: 0.30905
# Iteración 183/1000 - Error: 0.50483
# Iteración 184/1000 - Error: 0.51785
# Iteración 185/1000 - Error: 0.36023
# Iteración 186/1000 - Error: 0.25602
# Iteración 187/1000 - Error: 0.47996
# Iteración 188/1000 - Error: 0.4948
# Iteración 189/1000 - Error: 0.46961
# Iteración 190/1000 - Error: 0.32495
# Iteración 191/1000 - Error: 0.48122
# Iteración 192/1000 - Error: 0.6609
# Iteración 193/1000 - Error: 0.35863
# Iteración 194/1000 - Error: 0.61437
# Iteración 195/1000 - Error: 0.43044
# Iteración 196/1000 - Error: 0.37711
# Iteración 197/1000 - Error: 0.57971
# Iteración 198/1000 - Error: 0.4662
# Iteración 199/1000 - Error: 0.48922
# Iteración 200/1000 - Error: 0.42555
# Iteración 201/1000 - Error: 0.40719
# Iteración 202/1000 - Error: 0.42877
# Iteración 203/1000 - Error: 0.51061
# Iteración 204/1000 - Error: 0.31822
# Iteración 205/1000 - Error: 0.48715
# Iteración 206/1000 - Error: 0.53878
# Iteración 207/1000 - Error: 0.61093
# Iteración 208/1000 - Error: 0.36117
# Iteración 209/1000 - Error: 0.41076
# Iteración 210/1000 - Error: 0.31089
# Iteración 211/1000 - Error: 0.35254
# Iteración 212/1000 - Error: 0.48233
# Iteración 213/1000 - Error: 0.30972
# Iteración 214/1000 - Error: 0.60653
# Iteración 215/1000 - Error: 0.48158
# Iteración 216/1000 - Error: 0.56051
# Iteración 217/1000 - Error: 0.40006
# Iteración 218/1000 - Error: 0.46789
# Iteración 219/1000 - Error: 0.57812
# Iteración 220/1000 - Error: 0.31689
# Iteración 221/1000 - Error: 0.37123
# Iteración 222/1000 - Error: 0.37142
# Iteración 223/1000 - Error: 0.40525
# Iteración 224/1000 - Error: 0.59951
# Iteración 225/1000 - Error: 0.38147
# Iteración 226/1000 - Error: 0.57249
# Iteración 227/1000 - Error: 0.47937
# Iteración 228/1000 - Error: 0.45577
# Iteración 229/1000 - Error: 0.28952
# Iteración 230/1000 - Error: 0.48839
# Iteración 231/1000 - Error: 0.48689
# Iteración 232/1000 - Error: 0.43768
# Iteración 233/1000 - Error: 0.48495
# Iteración 234/1000 - Error: 0.39603
# Iteración 235/1000 - Error: 0.36159
# Iteración 236/1000 - Error: 0.44603
# Iteración 237/1000 - Error: 0.62706
# Iteración 238/1000 - Error: 0.54406
# Iteración 239/1000 - Error: 0.45884
# Iteración 240/1000 - Error: 0.2828
# Iteración 241/1000 - Error: 0.37749
# Iteración 242/1000 - Error: 0.41961
# Iteración 243/1000 - Error: 0.33035
# Iteración 244/1000 - Error: 0.47447
# Iteración 245/1000 - Error: 0.31706
# Iteración 246/1000 - Error: 0.44483
# Iteración 247/1000 - Error: 0.46519
# Iteración 248/1000 - Error: 0.69092
# Iteración 249/1000 - Error: 0.32972
# Iteración 250/1000 - Error: 0.54372
# Iteración 251/1000 - Error: 0.46926
# Iteración 252/1000 - Error: 0.43986
# Iteración 253/1000 - Error: 0.41008
# Iteración 254/1000 - Error: 0.63663
# Iteración 255/1000 - Error: 0.32311
# Iteración 256/1000 - Error: 0.46842
# Iteración 257/1000 - Error: 0.64483
# Iteración 258/1000 - Error: 0.41562
# Iteración 259/1000 - Error: 0.47108
# Iteración 260/1000 - Error: 0.43158
# Iteración 261/1000 - Error: 0.46312
# Iteración 262/1000 - Error: 0.5816
# Iteración 263/1000 - Error: 0.5235
# Iteración 264/1000 - Error: 0.32715
# Iteración 265/1000 - Error: 0.38744
# Iteración 266/1000 - Error: 0.54784
# Iteración 267/1000 - Error: 0.57001
# Iteración 268/1000 - Error: 0.48406
# Iteración 269/1000 - Error: 0.30997
# Iteración 270/1000 - Error: 0.50393
# Iteración 271/1000 - Error: 0.43276
# Iteración 272/1000 - Error: 0.4399
# Iteración 273/1000 - Error: 0.46907
# Iteración 274/1000 - Error: 0.39002
# Iteración 275/1000 - Error: 0.48878
# Iteración 276/1000 - Error: 0.42669
# Iteración 277/1000 - Error: 0.7393
# Iteración 278/1000 - Error: 0.43563
# Iteración 279/1000 - Error: 0.47778
# Iteración 280/1000 - Error: 0.3175
# Iteración 281/1000 - Error: 0.47395
# Iteración 282/1000 - Error: 0.66018
# Iteración 283/1000 - Error: 0.38267
# Iteración 284/1000 - Error: 0.5065
# Iteración 285/1000 - Error: 0.36971
# Iteración 286/1000 - Error: 0.46458
# Iteración 287/1000 - Error: 0.54441
# Iteración 288/1000 - Error: 0.61405
# Iteración 289/1000 - Error: 0.46719
# Iteración 290/1000 - Error: 0.33417
# Iteración 291/1000 - Error: 0.51716
# Iteración 292/1000 - Error: 0.63333
# Iteración 293/1000 - Error: 0.39145
# Iteración 294/1000 - Error: 0.36469
# Iteración 295/1000 - Error: 0.58226
# Iteración 296/1000 - Error: 0.52508
# Iteración 297/1000 - Error: 0.35226
# Iteración 298/1000 - Error: 0.50175
# Iteración 299/1000 - Error: 0.3663
# Iteración 300/1000 - Error: 0.36648
# Iteración 301/1000 - Error: 0.49707
# Iteración 302/1000 - Error: 0.60267
# Iteración 303/1000 - Error: 0.61027
# Iteración 304/1000 - Error: 0.35083
# Iteración 305/1000 - Error: 0.41342
# Iteración 306/1000 - Error: 0.4515
# Iteración 307/1000 - Error: 0.55618
# Iteración 308/1000 - Error: 0.58941
# Iteración 309/1000 - Error: 0.57948
# Iteración 310/1000 - Error: 0.52478
# Iteración 311/1000 - Error: 0.43523
# Iteración 312/1000 - Error: 0.31669
# Iteración 313/1000 - Error: 0.55095
# Iteración 314/1000 - Error: 0.72831
# Iteración 315/1000 - Error: 0.46307
# Iteración 316/1000 - Error: 0.44826
# Iteración 317/1000 - Error: 0.4438
# Iteración 318/1000 - Error: 0.57444
# Iteración 319/1000 - Error: 0.68124
# Iteración 320/1000 - Error: 0.5238
# Iteración 321/1000 - Error: 0.47037
# Iteración 322/1000 - Error: 0.4461
# Iteración 323/1000 - Error: 0.39081
# Iteración 324/1000 - Error: 0.3505
# Iteración 325/1000 - Error: 0.45938
# Iteración 326/1000 - Error: 0.46517
# Iteración 327/1000 - Error: 0.49807
# Iteración 328/1000 - Error: 0.50235
# Iteración 329/1000 - Error: 0.40605
# Iteración 330/1000 - Error: 0.57635
# Iteración 331/1000 - Error: 0.56627
# Iteración 332/1000 - Error: 0.43526
# Iteración 333/1000 - Error: 0.48966
# Iteración 334/1000 - Error: 0.4953
# Iteración 335/1000 - Error: 0.64348
# Iteración 336/1000 - Error: 0.46875
# Iteración 337/1000 - Error: 0.4505
# Iteración 338/1000 - Error: 0.5714
# Iteración 339/1000 - Error: 0.40026
# Iteración 340/1000 - Error: 0.51445
# Iteración 341/1000 - Error: 0.53226
# Iteración 342/1000 - Error: 0.53459
# Iteración 343/1000 - Error: 0.51613
# Iteración 344/1000 - Error: 0.34951
# Iteración 345/1000 - Error: 0.36039
# Iteración 346/1000 - Error: 0.45984
# Iteración 347/1000 - Error: 0.36679
# Iteración 348/1000 - Error: 0.42346
# Iteración 349/1000 - Error: 0.50532
# Iteración 350/1000 - Error: 0.49184
# Iteración 351/1000 - Error: 0.5014
# Iteración 352/1000 - Error: 0.34753
# Iteración 353/1000 - Error: 0.35566
# Iteración 354/1000 - Error: 0.54134
# Iteración 355/1000 - Error: 0.32762
# Iteración 356/1000 - Error: 0.67174
# Iteración 357/1000 - Error: 0.41522
# Iteración 358/1000 - Error: 0.47416
# Iteración 359/1000 - Error: 0.5581
# Iteración 360/1000 - Error: 0.56796
# Iteración 361/1000 - Error: 0.57803
# Iteración 362/1000 - Error: 0.44314
# Iteración 363/1000 - Error: 0.35196
# Iteración 364/1000 - Error: 0.41211
# Iteración 365/1000 - Error: 0.56226
# Iteración 366/1000 - Error: 0.48642
# Iteración 367/1000 - Error: 0.48581
# Iteración 368/1000 - Error: 0.41922
# Iteración 369/1000 - Error: 0.60809
# Iteración 370/1000 - Error: 0.54015
# Iteración 371/1000 - Error: 0.49794
# Iteración 372/1000 - Error: 0.4577
# Iteración 373/1000 - Error: 0.46332
# Iteración 374/1000 - Error: 0.41385
# Iteración 375/1000 - Error: 0.47543
# Iteración 376/1000 - Error: 0.51692
# Iteración 377/1000 - Error: 0.50825
# Iteración 378/1000 - Error: 0.35677
# Iteración 379/1000 - Error: 0.66804
# Iteración 380/1000 - Error: 0.30707
# Iteración 381/1000 - Error: 0.58902
# Iteración 382/1000 - Error: 0.47896
# Iteración 383/1000 - Error: 0.36132
# Iteración 384/1000 - Error: 0.40865
# Iteración 385/1000 - Error: 0.49818
# Iteración 386/1000 - Error: 0.42178
# Iteración 387/1000 - Error: 0.35521
# Iteración 388/1000 - Error: 0.24819
# Iteración 389/1000 - Error: 0.47902
# Iteración 390/1000 - Error: 0.34552
# Iteración 391/1000 - Error: 0.59795
# Iteración 392/1000 - Error: 0.48944
# Iteración 393/1000 - Error: 0.5095
# Iteración 394/1000 - Error: 0.44711
# Iteración 395/1000 - Error: 0.46398
# Iteración 396/1000 - Error: 0.37722
# Iteración 397/1000 - Error: 0.41584
# Iteración 398/1000 - Error: 0.33695
# Iteración 399/1000 - Error: 0.54396
# Iteración 400/1000 - Error: 0.39297
# Iteración 401/1000 - Error: 0.5181
# Iteración 402/1000 - Error: 0.40693
# Iteración 403/1000 - Error: 0.48872
# Iteración 404/1000 - Error: 0.3224
# Iteración 405/1000 - Error: 0.6059
# Iteración 406/1000 - Error: 0.43126
# Iteración 407/1000 - Error: 0.53774
# Iteración 408/1000 - Error: 0.54753
# Iteración 409/1000 - Error: 0.46972
# Iteración 410/1000 - Error: 0.52231
# Iteración 411/1000 - Error: 0.61294
# Iteración 412/1000 - Error: 0.42454
# Iteración 413/1000 - Error: 0.50814
# Iteración 414/1000 - Error: 0.39631
# Iteración 415/1000 - Error: 0.43861
# Iteración 416/1000 - Error: 0.3517
# Iteración 417/1000 - Error: 0.25249
# Iteración 418/1000 - Error: 0.46297
# Iteración 419/1000 - Error: 0.49057
# Iteración 420/1000 - Error: 0.38214
# Iteración 421/1000 - Error: 0.38212
# Iteración 422/1000 - Error: 0.41969
# Iteración 423/1000 - Error: 0.5098
# Iteración 424/1000 - Error: 0.51471
# Iteración 425/1000 - Error: 0.3449
# Iteración 426/1000 - Error: 0.27828
# Iteración 427/1000 - Error: 0.6449
# Iteración 428/1000 - Error: 0.61168
# Iteración 429/1000 - Error: 0.71782
# Iteración 430/1000 - Error: 0.51732
# Iteración 431/1000 - Error: 0.71129
# Iteración 432/1000 - Error: 0.4158
# Iteración 433/1000 - Error: 0.41841
# Iteración 434/1000 - Error: 0.40812
# Iteración 435/1000 - Error: 0.47343
# Iteración 436/1000 - Error: 0.48068
# Iteración 437/1000 - Error: 0.44979
# Iteración 438/1000 - Error: 0.43823
# Iteración 439/1000 - Error: 0.51504
# Iteración 440/1000 - Error: 0.32269
# Iteración 441/1000 - Error: 0.45683
# Iteración 442/1000 - Error: 0.42737
# Iteración 443/1000 - Error: 0.52664
# Iteración 444/1000 - Error: 0.29142
# Iteración 445/1000 - Error: 0.37618
# Iteración 446/1000 - Error: 0.28865
# Iteración 447/1000 - Error: 0.52935
# Iteración 448/1000 - Error: 0.3644
# Iteración 449/1000 - Error: 0.44271
# Iteración 450/1000 - Error: 0.53212
# Iteración 451/1000 - Error: 0.58775
# Iteración 452/1000 - Error: 0.33194
# Iteración 453/1000 - Error: 0.52038
# Iteración 454/1000 - Error: 0.57246
# Iteración 455/1000 - Error: 0.66624
# Iteración 456/1000 - Error: 0.48063
# Iteración 457/1000 - Error: 0.43854
# Iteración 458/1000 - Error: 0.43646
# Iteración 459/1000 - Error: 0.45067
# Iteración 460/1000 - Error: 0.37943
# Iteración 461/1000 - Error: 0.34727
# Iteración 462/1000 - Error: 0.38155
# Iteración 463/1000 - Error: 0.60121
# Iteración 464/1000 - Error: 0.51689
# Iteración 465/1000 - Error: 0.50959
# Iteración 466/1000 - Error: 0.60986
# Iteración 467/1000 - Error: 0.62988
# Iteración 468/1000 - Error: 0.50517
# Iteración 469/1000 - Error: 0.42469
# Iteración 470/1000 - Error: 0.42072
# Iteración 471/1000 - Error: 0.45299
# Iteración 472/1000 - Error: 0.36651
# Iteración 473/1000 - Error: 0.3577
# Iteración 474/1000 - Error: 0.34435
# Iteración 475/1000 - Error: 0.636
# Iteración 476/1000 - Error: 0.3766
# Iteración 477/1000 - Error: 0.61734
# Iteración 478/1000 - Error: 0.53723
# Iteración 479/1000 - Error: 0.53517
# Iteración 480/1000 - Error: 0.38865
# Iteración 481/1000 - Error: 0.65998
# Iteración 482/1000 - Error: 0.36592
# Iteración 483/1000 - Error: 0.39649
# Iteración 484/1000 - Error: 0.54373
# Iteración 485/1000 - Error: 0.41198
# Iteración 486/1000 - Error: 0.64115
# Iteración 487/1000 - Error: 0.26993
# Iteración 488/1000 - Error: 0.43147
# Iteración 489/1000 - Error: 0.46642
# Iteración 490/1000 - Error: 0.4491
# Iteración 491/1000 - Error: 0.33986
# Iteración 492/1000 - Error: 0.44869
# Iteración 493/1000 - Error: 0.44365
# Iteración 494/1000 - Error: 0.42836
# Iteración 495/1000 - Error: 0.27993
# Iteración 496/1000 - Error: 0.34217
# Iteración 497/1000 - Error: 0.48356
# Iteración 498/1000 - Error: 0.32156
# Iteración 499/1000 - Error: 0.36109
# Iteración 500/1000 - Error: 0.43844
# Iteración 501/1000 - Error: 0.42431
# Iteración 502/1000 - Error: 0.61164
# Iteración 503/1000 - Error: 0.43841
# Iteración 504/1000 - Error: 0.42803
# Iteración 505/1000 - Error: 0.55527
# Iteración 506/1000 - Error: 0.3297
# Iteración 507/1000 - Error: 0.49925
# Iteración 508/1000 - Error: 0.34296
# Iteración 509/1000 - Error: 0.44494
# Iteración 510/1000 - Error: 0.30335
# Iteración 511/1000 - Error: 0.35767
# Iteración 512/1000 - Error: 0.54859
# Iteración 513/1000 - Error: 0.70482
# Iteración 514/1000 - Error: 0.36668
# Iteración 515/1000 - Error: 0.55632
# Iteración 516/1000 - Error: 0.49433
# Iteración 517/1000 - Error: 0.61719
# Iteración 518/1000 - Error: 0.49467
# Iteración 519/1000 - Error: 0.53281
# Iteración 520/1000 - Error: 0.36744
# Iteración 521/1000 - Error: 0.25473
# Iteración 522/1000 - Error: 0.42525
# Iteración 523/1000 - Error: 0.35988
# Iteración 524/1000 - Error: 0.4229
# Iteración 525/1000 - Error: 0.4758
# Iteración 526/1000 - Error: 0.48573
# Iteración 527/1000 - Error: 0.50539
# Iteración 528/1000 - Error: 0.33224
# Iteración 529/1000 - Error: 0.56282
# Iteración 530/1000 - Error: 0.2125
# Iteración 531/1000 - Error: 0.45755
# Iteración 532/1000 - Error: 0.47032
# Iteración 533/1000 - Error: 0.46445
# Iteración 534/1000 - Error: 0.50087
# Iteración 535/1000 - Error: 0.58002
# Iteración 536/1000 - Error: 0.42801
# Iteración 537/1000 - Error: 0.46977
# Iteración 538/1000 - Error: 0.49575
# Iteración 539/1000 - Error: 0.50153
# Iteración 540/1000 - Error: 0.419
# Iteración 541/1000 - Error: 0.55113
# Iteración 542/1000 - Error: 0.50053
# Iteración 543/1000 - Error: 0.35151
# Iteración 544/1000 - Error: 0.51343
# Iteración 545/1000 - Error: 0.3892
# Iteración 546/1000 - Error: 0.44044
# Iteración 547/1000 - Error: 0.34181
# Iteración 548/1000 - Error: 0.62842
# Iteración 549/1000 - Error: 0.47381
# Iteración 550/1000 - Error: 0.31709
# Iteración 551/1000 - Error: 0.33744
# Iteración 552/1000 - Error: 0.54303
# Iteración 553/1000 - Error: 0.51502
# Iteración 554/1000 - Error: 0.62506
# Iteración 555/1000 - Error: 0.40752
# Iteración 556/1000 - Error: 0.70411
# Iteración 557/1000 - Error: 0.49595
# Iteración 558/1000 - Error: 0.52856
# Iteración 559/1000 - Error: 0.42875
# Iteración 560/1000 - Error: 0.35899
# Iteración 561/1000 - Error: 0.53156
# Iteración 562/1000 - Error: 0.51438
# Iteración 563/1000 - Error: 0.47535
# Iteración 564/1000 - Error: 0.35324
# Iteración 565/1000 - Error: 0.49404
# Iteración 566/1000 - Error: 0.41953
# Iteración 567/1000 - Error: 0.43665
# Iteración 568/1000 - Error: 0.8372
# Iteración 569/1000 - Error: 0.32564
# Iteración 570/1000 - Error: 0.37225
# Iteración 571/1000 - Error: 0.44613
# Iteración 572/1000 - Error: 0.50523
# Iteración 573/1000 - Error: 0.33054
# Iteración 574/1000 - Error: 0.38357
# Iteración 575/1000 - Error: 0.42822
# Iteración 576/1000 - Error: 0.42808
# Iteración 577/1000 - Error: 0.63456
# Iteración 578/1000 - Error: 0.40895
# Iteración 579/1000 - Error: 0.49492
# Iteración 580/1000 - Error: 0.50644
# Iteración 581/1000 - Error: 0.52683
# Iteración 582/1000 - Error: 0.30969
# Iteración 583/1000 - Error: 0.40193
# Iteración 584/1000 - Error: 0.50048
# Iteración 585/1000 - Error: 0.53809
# Iteración 586/1000 - Error: 0.3416
# Iteración 587/1000 - Error: 0.36589
# Iteración 588/1000 - Error: 0.42895
# Iteración 589/1000 - Error: 0.50311
# Iteración 590/1000 - Error: 0.44697
# Iteración 591/1000 - Error: 0.42774
# Iteración 592/1000 - Error: 0.52934
# Iteración 593/1000 - Error: 0.39044
# Iteración 594/1000 - Error: 0.41223
# Iteración 595/1000 - Error: 0.22929
# Iteración 596/1000 - Error: 0.47779
# Iteración 597/1000 - Error: 0.51319
# Iteración 598/1000 - Error: 0.37688
# Iteración 599/1000 - Error: 0.44647
# Iteración 600/1000 - Error: 0.496
# Iteración 601/1000 - Error: 0.50419
# Iteración 602/1000 - Error: 0.36235
# Iteración 603/1000 - Error: 0.43573
# Iteración 604/1000 - Error: 0.47187
# Iteración 605/1000 - Error: 0.34469
# Iteración 606/1000 - Error: 0.55153
# Iteración 607/1000 - Error: 0.53174
# Iteración 608/1000 - Error: 0.58364
# Iteración 609/1000 - Error: 0.30842
# Iteración 610/1000 - Error: 0.40619
# Iteración 611/1000 - Error: 0.4255
# Iteración 612/1000 - Error: 0.36902
# Iteración 613/1000 - Error: 0.67324
# Iteración 614/1000 - Error: 0.30115
# Iteración 615/1000 - Error: 0.69198
# Iteración 616/1000 - Error: 0.54182
# Iteración 617/1000 - Error: 0.31031
# Iteración 618/1000 - Error: 0.31126
# Iteración 619/1000 - Error: 0.36698
# Iteración 620/1000 - Error: 0.35786
# Iteración 621/1000 - Error: 0.32052
# Iteración 622/1000 - Error: 0.42719
# Iteración 623/1000 - Error: 0.48714
# Iteración 624/1000 - Error: 0.3754
# Iteración 625/1000 - Error: 0.58122
# Iteración 626/1000 - Error: 0.53934
# Iteración 627/1000 - Error: 0.55596
# Iteración 628/1000 - Error: 0.5252
# Iteración 629/1000 - Error: 0.58689
# Iteración 630/1000 - Error: 0.56541
# Iteración 631/1000 - Error: 0.4469
# Iteración 632/1000 - Error: 0.28363
# Iteración 633/1000 - Error: 0.56311
# Iteración 634/1000 - Error: 0.54936
# Iteración 635/1000 - Error: 0.40149
# Iteración 636/1000 - Error: 0.28403
# Iteración 637/1000 - Error: 0.41373
# Iteración 638/1000 - Error: 0.63579
# Iteración 639/1000 - Error: 0.63061
# Iteración 640/1000 - Error: 0.37551
# Iteración 641/1000 - Error: 0.3654
# Iteración 642/1000 - Error: 0.34245
# Iteración 643/1000 - Error: 0.45474
# Iteración 644/1000 - Error: 0.56304
# Iteración 645/1000 - Error: 0.56665
# Iteración 646/1000 - Error: 0.39371
# Iteración 647/1000 - Error: 0.44555
# Iteración 648/1000 - Error: 0.48965
# Iteración 649/1000 - Error: 0.48827
# Iteración 650/1000 - Error: 0.40099
# Iteración 651/1000 - Error: 0.39551
# Iteración 652/1000 - Error: 0.42206
# Iteración 653/1000 - Error: 0.34072
# Iteración 654/1000 - Error: 0.79727
# Iteración 655/1000 - Error: 0.4503
# Iteración 656/1000 - Error: 0.46655
# Iteración 657/1000 - Error: 0.42639
# Iteración 658/1000 - Error: 0.33564
# Iteración 659/1000 - Error: 0.55929
# Iteración 660/1000 - Error: 0.46843
# Iteración 661/1000 - Error: 0.54713
# Iteración 662/1000 - Error: 0.337
# Iteración 663/1000 - Error: 0.53546
# Iteración 664/1000 - Error: 0.39533
# Iteración 665/1000 - Error: 0.44446
# Iteración 666/1000 - Error: 0.38349
# Iteración 667/1000 - Error: 0.51842
# Iteración 668/1000 - Error: 0.52538
# Iteración 669/1000 - Error: 0.4569
# Iteración 670/1000 - Error: 0.51549
# Iteración 671/1000 - Error: 0.34679
# Iteración 672/1000 - Error: 0.74867
# Iteración 673/1000 - Error: 0.46569
# Iteración 674/1000 - Error: 0.45506
# Iteración 675/1000 - Error: 0.64991
# Iteración 676/1000 - Error: 0.45783
# Iteración 677/1000 - Error: 0.52309
# Iteración 678/1000 - Error: 0.71012
# Iteración 679/1000 - Error: 0.46109
# Iteración 680/1000 - Error: 0.48889
# Iteración 681/1000 - Error: 0.37916
# Iteración 682/1000 - Error: 0.34533
# Iteración 683/1000 - Error: 0.2949
# Iteración 684/1000 - Error: 0.47634
# Iteración 685/1000 - Error: 0.54941
# Iteración 686/1000 - Error: 0.56802
# Iteración 687/1000 - Error: 0.40337
# Iteración 688/1000 - Error: 0.57254
# Iteración 689/1000 - Error: 0.37064
# Iteración 690/1000 - Error: 0.38234
# Iteración 691/1000 - Error: 0.65374
# Iteración 692/1000 - Error: 0.56797
# Iteración 693/1000 - Error: 0.60428
# Iteración 694/1000 - Error: 0.39939
# Iteración 695/1000 - Error: 0.57149
# Iteración 696/1000 - Error: 0.47264
# Iteración 697/1000 - Error: 0.55999
# Iteración 698/1000 - Error: 0.53367
# Iteración 699/1000 - Error: 0.49258
# Iteración 700/1000 - Error: 0.54852
# Iteración 701/1000 - Error: 0.53132
# Iteración 702/1000 - Error: 0.47699
# Iteración 703/1000 - Error: 0.4068
# Iteración 704/1000 - Error: 0.35142
# Iteración 705/1000 - Error: 0.544
# Iteración 706/1000 - Error: 0.4283
# Iteración 707/1000 - Error: 0.39026
# Iteración 708/1000 - Error: 0.3686
# Iteración 709/1000 - Error: 0.39425
# Iteración 710/1000 - Error: 0.47522
# Iteración 711/1000 - Error: 0.51223
# Iteración 712/1000 - Error: 0.39817
# Iteración 713/1000 - Error: 0.39602
# Iteración 714/1000 - Error: 0.54068
# Iteración 715/1000 - Error: 0.33473
# Iteración 716/1000 - Error: 0.4631
# Iteración 717/1000 - Error: 0.69705
# Iteración 718/1000 - Error: 0.39684
# Iteración 719/1000 - Error: 0.40564
# Iteración 720/1000 - Error: 0.36533
# Iteración 721/1000 - Error: 0.38633
# Iteración 722/1000 - Error: 0.35471
# Iteración 723/1000 - Error: 0.63463
# Iteración 724/1000 - Error: 0.30873
# Iteración 725/1000 - Error: 0.56086
# Iteración 726/1000 - Error: 0.37113
# Iteración 727/1000 - Error: 0.45053
# Iteración 728/1000 - Error: 0.37029
# Iteración 729/1000 - Error: 0.47891
# Iteración 730/1000 - Error: 0.57748
# Iteración 731/1000 - Error: 0.50268
# Iteración 732/1000 - Error: 0.44767
# Iteración 733/1000 - Error: 0.3446
# Iteración 734/1000 - Error: 0.6371
# Iteración 735/1000 - Error: 0.5388
# Iteración 736/1000 - Error: 0.4007
# Iteración 737/1000 - Error: 0.48718
# Iteración 738/1000 - Error: 0.38586
# Iteración 739/1000 - Error: 0.59079
# Iteración 740/1000 - Error: 0.37295
# Iteración 741/1000 - Error: 0.5029
# Iteración 742/1000 - Error: 0.45925
# Iteración 743/1000 - Error: 0.6548
# Iteración 744/1000 - Error: 0.5586
# Iteración 745/1000 - Error: 0.51504
# Iteración 746/1000 - Error: 0.3996
# Iteración 747/1000 - Error: 0.34955
# Iteración 748/1000 - Error: 0.47087
# Iteración 749/1000 - Error: 0.33052
# Iteración 750/1000 - Error: 0.41922
# Iteración 751/1000 - Error: 0.38312
# Iteración 752/1000 - Error: 0.53443
# Iteración 753/1000 - Error: 0.47649
# Iteración 754/1000 - Error: 0.58872
# Iteración 755/1000 - Error: 0.67495
# Iteración 756/1000 - Error: 0.48355
# Iteración 757/1000 - Error: 0.26606
# Iteración 758/1000 - Error: 0.58562
# Iteración 759/1000 - Error: 0.39534
# Iteración 760/1000 - Error: 0.29608
# Iteración 761/1000 - Error: 0.41603
# Iteración 762/1000 - Error: 0.49069
# Iteración 763/1000 - Error: 0.40543
# Iteración 764/1000 - Error: 0.39028
# Iteración 765/1000 - Error: 0.48337
# Iteración 766/1000 - Error: 0.43505
# Iteración 767/1000 - Error: 0.51811
# Iteración 768/1000 - Error: 0.69439
# Iteración 769/1000 - Error: 0.53643
# Iteración 770/1000 - Error: 0.45397
# Iteración 771/1000 - Error: 0.45468
# Iteración 772/1000 - Error: 0.53408
# Iteración 773/1000 - Error: 0.54528
# Iteración 774/1000 - Error: 0.39123
# Iteración 775/1000 - Error: 0.24757
# Iteración 776/1000 - Error: 0.27879
# Iteración 777/1000 - Error: 0.39314
# Iteración 778/1000 - Error: 0.57528
# Iteración 779/1000 - Error: 0.4461
# Iteración 780/1000 - Error: 0.33827
# Iteración 781/1000 - Error: 0.34517
# Iteración 782/1000 - Error: 0.56076
# Iteración 783/1000 - Error: 0.31965
# Iteración 784/1000 - Error: 0.42294
# Iteración 785/1000 - Error: 0.35943
# Iteración 786/1000 - Error: 0.47948
# Iteración 787/1000 - Error: 0.46282
# Iteración 788/1000 - Error: 0.71605
# Iteración 789/1000 - Error: 0.49269
# Iteración 790/1000 - Error: 0.2637
# Iteración 791/1000 - Error: 0.41708
# Iteración 792/1000 - Error: 0.45921
# Iteración 793/1000 - Error: 0.46191
# Iteración 794/1000 - Error: 0.47398
# Iteración 795/1000 - Error: 0.61361
# Iteración 796/1000 - Error: 0.50618
# Iteración 797/1000 - Error: 0.52892
# Iteración 798/1000 - Error: 0.58154
# Iteración 799/1000 - Error: 0.37572
# Iteración 800/1000 - Error: 0.47651
# Iteración 801/1000 - Error: 0.4706
# Iteración 802/1000 - Error: 0.44469
# Iteración 803/1000 - Error: 0.47397
# Iteración 804/1000 - Error: 0.42306
# Iteración 805/1000 - Error: 0.63237
# Iteración 806/1000 - Error: 0.63874
# Iteración 807/1000 - Error: 0.30867
# Iteración 808/1000 - Error: 0.54487
# Iteración 809/1000 - Error: 0.47312
# Iteración 810/1000 - Error: 0.41744
# Iteración 811/1000 - Error: 0.5252
# Iteración 812/1000 - Error: 0.39389
# Iteración 813/1000 - Error: 0.27938
# Iteración 814/1000 - Error: 0.31056
# Iteración 815/1000 - Error: 0.5515
# Iteración 816/1000 - Error: 0.55486
# Iteración 817/1000 - Error: 0.32546
# Iteración 818/1000 - Error: 0.42511
# Iteración 819/1000 - Error: 0.45521
# Iteración 820/1000 - Error: 0.66724
# Iteración 821/1000 - Error: 0.36697
# Iteración 822/1000 - Error: 0.50058
# Iteración 823/1000 - Error: 0.45947
# Iteración 824/1000 - Error: 0.52908
# Iteración 825/1000 - Error: 0.51192
# Iteración 826/1000 - Error: 0.44206
# Iteración 827/1000 - Error: 0.50574
# Iteración 828/1000 - Error: 0.40602
# Iteración 829/1000 - Error: 0.38121
# Iteración 830/1000 - Error: 0.51373
# Iteración 831/1000 - Error: 0.58751
# Iteración 832/1000 - Error: 0.40641
# Iteración 833/1000 - Error: 0.47113
# Iteración 834/1000 - Error: 0.72961
# Iteración 835/1000 - Error: 0.29601
# Iteración 836/1000 - Error: 0.29533
# Iteración 837/1000 - Error: 0.58492
# Iteración 838/1000 - Error: 0.37686
# Iteración 839/1000 - Error: 0.45275
# Iteración 840/1000 - Error: 0.49992
# Iteración 841/1000 - Error: 0.43972
# Iteración 842/1000 - Error: 0.39897
# Iteración 843/1000 - Error: 0.51309
# Iteración 844/1000 - Error: 0.50775
# Iteración 845/1000 - Error: 0.42703
# Iteración 846/1000 - Error: 0.29716
# Iteración 847/1000 - Error: 0.52728
# Iteración 848/1000 - Error: 0.66017
# Iteración 849/1000 - Error: 0.63368
# Iteración 850/1000 - Error: 0.49108
# Iteración 851/1000 - Error: 0.44163
# Iteración 852/1000 - Error: 0.42226
# Iteración 853/1000 - Error: 0.55025
# Iteración 854/1000 - Error: 0.43793
# Iteración 855/1000 - Error: 0.44767
# Iteración 856/1000 - Error: 0.53783
# Iteración 857/1000 - Error: 0.34198
# Iteración 858/1000 - Error: 0.56912
# Iteración 859/1000 - Error: 0.50843
# Iteración 860/1000 - Error: 0.36043
# Iteración 861/1000 - Error: 0.61621
# Iteración 862/1000 - Error: 0.46861
# Iteración 863/1000 - Error: 0.44084
# Iteración 864/1000 - Error: 0.39229
# Iteración 865/1000 - Error: 0.46467
# Iteración 866/1000 - Error: 0.48673
# Iteración 867/1000 - Error: 0.54112
# Iteración 868/1000 - Error: 0.50808
# Iteración 869/1000 - Error: 0.4965
# Iteración 870/1000 - Error: 0.50318
# Iteración 871/1000 - Error: 0.46604
# Iteración 872/1000 - Error: 0.42617
# Iteración 873/1000 - Error: 0.49897
# Iteración 874/1000 - Error: 0.40485
# Iteración 875/1000 - Error: 0.6947
# Iteración 876/1000 - Error: 0.6842
# Iteración 877/1000 - Error: 0.50018
# Iteración 878/1000 - Error: 0.53149
# Iteración 879/1000 - Error: 0.3579
# Iteración 880/1000 - Error: 0.46027
# Iteración 881/1000 - Error: 0.42481
# Iteración 882/1000 - Error: 0.44277
# Iteración 883/1000 - Error: 0.60235
# Iteración 884/1000 - Error: 0.56596
# Iteración 885/1000 - Error: 0.40354
# Iteración 886/1000 - Error: 0.33529
# Iteración 887/1000 - Error: 0.41452
# Iteración 888/1000 - Error: 0.52411
# Iteración 889/1000 - Error: 0.44893
# Iteración 890/1000 - Error: 0.50453
# Iteración 891/1000 - Error: 0.37823
# Iteración 892/1000 - Error: 0.5159
# Iteración 893/1000 - Error: 0.38466
# Iteración 894/1000 - Error: 0.52925
# Iteración 895/1000 - Error: 0.3853
# Iteración 896/1000 - Error: 0.71789
# Iteración 897/1000 - Error: 0.60028
# Iteración 898/1000 - Error: 0.36295
# Iteración 899/1000 - Error: 0.61285
# Iteración 900/1000 - Error: 0.54996
# Iteración 901/1000 - Error: 0.37813
# Iteración 902/1000 - Error: 0.40071
# Iteración 903/1000 - Error: 0.41832
# Iteración 904/1000 - Error: 0.39808
# Iteración 905/1000 - Error: 0.6148
# Iteración 906/1000 - Error: 0.47316
# Iteración 907/1000 - Error: 0.459
# Iteración 908/1000 - Error: 0.59525
# Iteración 909/1000 - Error: 0.56947
# Iteración 910/1000 - Error: 0.49541
# Iteración 911/1000 - Error: 0.52428
# Iteración 912/1000 - Error: 0.78883
# Iteración 913/1000 - Error: 0.45947
# Iteración 914/1000 - Error: 0.4143
# Iteración 915/1000 - Error: 0.41249
# Iteración 916/1000 - Error: 0.55266
# Iteración 917/1000 - Error: 0.62803
# Iteración 918/1000 - Error: 0.53629
# Iteración 919/1000 - Error: 0.25578
# Iteración 920/1000 - Error: 0.31522
# Iteración 921/1000 - Error: 0.45037
# Iteración 922/1000 - Error: 0.61454
# Iteración 923/1000 - Error: 0.293
# Iteración 924/1000 - Error: 0.43322
# Iteración 925/1000 - Error: 0.34789
# Iteración 926/1000 - Error: 0.4619
# Iteración 927/1000 - Error: 0.43939
# Iteración 928/1000 - Error: 0.43678
# Iteración 929/1000 - Error: 0.48777
# Iteración 930/1000 - Error: 0.42539
# Iteración 931/1000 - Error: 0.38988
# Iteración 932/1000 - Error: 0.5471
# Iteración 933/1000 - Error: 0.36377
# Iteración 934/1000 - Error: 0.4746
# Iteración 935/1000 - Error: 0.45732
# Iteración 936/1000 - Error: 0.52519
# Iteración 937/1000 - Error: 0.56912
# Iteración 938/1000 - Error: 0.40282
# Iteración 939/1000 - Error: 0.43632
# Iteración 940/1000 - Error: 0.38127
# Iteración 941/1000 - Error: 0.41531
# Iteración 942/1000 - Error: 0.53585
# Iteración 943/1000 - Error: 0.40493
# Iteración 944/1000 - Error: 0.51184
# Iteración 945/1000 - Error: 0.33237
# Iteración 946/1000 - Error: 0.59435
# Iteración 947/1000 - Error: 0.38553
# Iteración 948/1000 - Error: 0.39626
# Iteración 949/1000 - Error: 0.45979
# Iteración 950/1000 - Error: 0.42114
# Iteración 951/1000 - Error: 0.57617
# Iteración 952/1000 - Error: 0.52364
# Iteración 953/1000 - Error: 0.63382
# Iteración 954/1000 - Error: 0.36596
# Iteración 955/1000 - Error: 0.53214
# Iteración 956/1000 - Error: 0.51681
# Iteración 957/1000 - Error: 0.45159
# Iteración 958/1000 - Error: 0.36134
# Iteración 959/1000 - Error: 0.49743
# Iteración 960/1000 - Error: 0.59508
# Iteración 961/1000 - Error: 0.44969
# Iteración 962/1000 - Error: 0.39857
# Iteración 963/1000 - Error: 0.42824
# Iteración 964/1000 - Error: 0.59992
# Iteración 965/1000 - Error: 0.59243
# Iteración 966/1000 - Error: 0.42007
# Iteración 967/1000 - Error: 0.35923
# Iteración 968/1000 - Error: 0.51081
# Iteración 969/1000 - Error: 0.47953
# Iteración 970/1000 - Error: 0.44854
# Iteración 971/1000 - Error: 0.41845
# Iteración 972/1000 - Error: 0.47741
# Iteración 973/1000 - Error: 0.45748
# Iteración 974/1000 - Error: 0.58366
# Iteración 975/1000 - Error: 0.57856
# Iteración 976/1000 - Error: 0.34159
# Iteración 977/1000 - Error: 0.50207
# Iteración 978/1000 - Error: 0.51147
# Iteración 979/1000 - Error: 0.41618
# Iteración 980/1000 - Error: 0.56171
# Iteración 981/1000 - Error: 0.47928
# Iteración 982/1000 - Error: 0.38319
# Iteración 983/1000 - Error: 0.46226
# Iteración 984/1000 - Error: 0.33103
# Iteración 985/1000 - Error: 0.50215
# Iteración 986/1000 - Error: 0.43836
# Iteración 987/1000 - Error: 0.47201
# Iteración 988/1000 - Error: 0.4229
# Iteración 989/1000 - Error: 0.34495
# Iteración 990/1000 - Error: 0.56058
# Iteración 991/1000 - Error: 0.78179
# Iteración 992/1000 - Error: 0.28869
# Iteración 993/1000 - Error: 0.29472
# Iteración 994/1000 - Error: 0.46146
# Iteración 995/1000 - Error: 0.47509
# Iteración 996/1000 - Error: 0.39368
# Iteración 997/1000 - Error: 0.49058
# Iteración 998/1000 - Error: 0.4017
# Iteración 999/1000 - Error: 0.55246
# Iteración 1000/1000 - Error: 0.41097
# Exactitud en el conjunto de prueba: 0.8435754189944135
